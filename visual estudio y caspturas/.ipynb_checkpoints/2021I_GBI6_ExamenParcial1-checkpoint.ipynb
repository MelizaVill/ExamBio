# %% [markdown]
# <img src="https://www.ikiam.edu.ec/img/logo-ikiam-grey.png" width=300 height=240 />
#
# # EXAMEN PARCIAL 1
#
# ## GBI6-2021II: BIOINFORMÁTICA
#
# **Apellidos Y Nombres** <--- Villa Toledo Sthefanny Meliza
#
# **11-01-2021**

# %% [markdown]
# <font color='red'>NO AGREGUE NUEVAS CELDAS, UTILICE ÚNICAMENTE LAS QUE ESTÁN CREADAS</font>

# %% [markdown]
# # 1. UNIX
#
# ## Ejercicio 1
# Escriba aquì el enunciado
# Para esta pregunta debe realizar previamente lo siguiente:
#
# Imprimir el directorio de trabajo actual
# Crear un directorio test1
# No cambie de directorio, pero los items 4, 5 y 6 deben guardarse en el directorio creado en el paso 2.
# Crear el archivo test1.txt
# Guardar el texto Hola GBI6 en un archivo test2.txt
# Guardar la instrucción print("Hola GBI6")  en el archivo test1.py
# Luego seleccione la instrucción que enlista los archivos del directorio test1 y luego borra test1.py del directorio test1
# ![Ejarcicio 1.png](attachment:fde520f1-1bdb-4bcd-a3cc-b33d2592a4e4.png)
#
# En este ejercicio solo e considerado dos respuestas dado que en la otra opcion solo nos indica cuales son los documentos existentes no su directorio
#
# ## Ejercicio 2
# Seleccione la opción el código que imprime el texto: Hola GBI6
# ![Ejercicio 2.png](attachment:e7580094-74be-4c36-a758-a9a14df434f0.png)
# $ echo "Hola GBI6"
#
# ## Ejercicio 3
# Para esta pregunta debe realizar previamente lo siguiente:
#
# Imprimir el directorio de trabajo actual
# Crear un directorio test1
# No cambie de directorio, pero los items 4, 5 y 6 deben guardarse en el directorio creado en el paso 2.
# Crear el archivo test1.txt
# Guardar el texto Hola GBI6 en un archivo test2.txt
# Guardar la instrucción print("Hola GBI6")  en el archivo test1.py
# Luego seleccione la instrucción que imprima el número de elementos del directorio test1
#
# ![ejercicio 3.png](attachment:57b64107-0537-41ca-8d2d-7d53e1199bda.png)
# $ ls test1 | wc -l
#
# ## Ejercicio 4
# Resuelva el ejercicio 1.10.4 Data Explorer.
#
# Resuelva el ejercicio en un documento de nombre ejercicio_1104.sh
# Cargue el documento ejercicio_1104.sh en GitHub utilizando git push.
# Realice el video explicativo de la resolución ejercicio y guarde en YouTube en formato "Público" o "Unlisted", y pegue el enlace en el cuaderno de Jupyter.
# La respuesta a este ejercicio es el enlace en GitHub de su archivo: ejercicio_1104.sh
# ![Ejercicio 4.png](attachment:48e188bd-b777-488f-9735-8353b1e27939.png)

# %%
# Coloque aquí su video del ejercicio 4
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://youtu.be/MqL8KmUXudQ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/9ck5iEP03g4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Escriba aquí alguna explicación del ejercicio 4 si lo considera necesario (borre esta línea cuando finalice)
#
# ## Ejercicio 5
# Resuelva el ejercicio 1.10.3 Plant–Pollinator Networks.
#
# Resuelva el ejercicio en un documento de nombre ejercicio_1103.sh
# Cargue el documento ejercicio_1103.sh en GitHub utilizando git push.
# Realice el video explicativo de la resolución ejercicio y guarde en YouTube en formato "Público" o "Unlisted", y pegue el enlace en el cuaderno de Jupyter.
# La respuesta a este ejercicio es el enlace en GitHub de su archivo ejercicio_1103.sh
# ![Ejercicio 5.png](attachment:35e8f9d8-ac23-4b0d-b205-d3daa97b63b8.png)

# %%
# Coloque aquí su video del ejercicio 5
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://youtu.be/MShsRDhlmt8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/3XlZWpLwvvo" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Los links de comando en nano son:
# Ejercicio 4
# https://github.com/MelizaVill/ExamBio/blob/main/ejercicio_1104.sh
# Ejercicio 5
# https://github.com/MelizaVill/ExamBio/blob/main/ejercicio_1103.sh
#
# # 2. CONTROL DE LA VERSIÓN
# ## Pregunta
# 1. Cree en GitHub un repositorio de nombre ```ExamBio```.
# 2. Cree un archivo ```Readme.md``` que debe tener lo siguiente:
# - Datos personales
# - Características del computador
# - Programas utilizados
# - Explicación de la data utilizada
#
#
# ## Pregunta
# 1. Cada vez que resuelva un ejercicio (del 1 al 10), utilizando Git Bash, GitHub Desktop o Atom realice un *git push* con el mensaje:
#
#
# <font color='red'>Villa Toledo1</font> % C # de ejercicio segun corresponda
#
# 2. Coloque aquí las capturas de pantalla para cada git push realizado desde Git Bash, GitHub Desktop o Atom.
#
# - Control de versión ejercicio 1 y Control de versión ejercicio 2
#
# ![git push 1 y 2.png](attachment:b8ca163b-40ef-479a-861d-d271d7bb266d.png)
#
# - Control de versión ejercicio 3
#
# ![git push ejercicio 3.png](attachment:a20d69d8-515f-4f5a-93cd-f54a8abb0343.png)
# - Control de versión ejercicio 4 y Control de versión ejercicio 5
#
# ![git push ejercicio 4 y 5.png](attachment:6b52ad90-8db7-4555-bf92-bf16dbaa2780.png)
# - Control de versión ejercicio 6
#
# ![git push 6.png](attachment:9d64c1e2-6da8-4f3c-8b29-18cc4e482fdc.png)
#
# - Control de versión ejercicio 7
#
# ![git push cuaderno.png](attachment:752e10c9-ce97-49d9-97a5-0a386852d2d7.png)
#
# ![git push ejercicio 7.png](attachment:5c529bfb-8267-4b2d-89e1-b9d7850fdc13.png)
#
# - Control de versión ejercicio 8
#
# ![git push 8.png](attachment:ef2d4018-c688-43c9-8410-64b4cb82ffff.png)
#
# 3. Cree un directorio de nombre ```data``` donde deben estar guardados: (i) la data utilizada y (ii) las capturas de pantalla de los ejercicios 1 al 3 y los git push del ejercicio 1 al 10 (en total debe tener 13 imágenes).
# 4. Inserte aquí el enlace de su repositorio (válido para el ejercicio 6 y 7): [GitHub Repository: ExamBio](https://github.com/MelizaVill/ExamBio.git)

# %% [markdown]
# # 3. INTRODUCCIÓN A PYTHON
#
# ## Ejercicio 6
#
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# Descargue la data "SI Table 1" (10080Table1.xls) de la página https://www.pnas.org/content/suppl/2006/12/27/0610080104.DC1. Esta data corresponde a algunas características de sueño de mamíferos. Seleccione los 10 primeros registros de la columna "Total sleep time, hr" y cree una lista de nombre lista1.
#
# Relaciones los códigos y las respuestas que salen al ejecutar.
# ### Resultados
# Se añade la data de los 10 primero
# Append lista1[-1][2] devuelve: ikiam
# El comando lista1[5] devuelve: 10.1
# El comando sum(lista1)/len(lista1) devuelve: 13.079999999999998
# Extend el comando len(lista1) devuelve: 13
# El comando lista1[8:] devuelve: [14.9, 9.1]
# El comando round(sum(lista1)/len(lista1), 3) devuelve: 13.08
# ![Ejercicio 6.png](attachment:7d550703-4991-4c8e-b9b0-595824737155.png)

# %%
# Escriba aquí el código
# Codigo del ejercicio 7
## Para la creacion de la lista se usa <nombre = [datos]>

lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1] # Creación de la lista con los diez primeros datos de Total sleep time, hr

# codigos de la pregunta
lista1.append(["gbi6", "bio1", "ikiam"])
print("tras el append el comando lista1[-1][2] devuelve:", lista1[-1][2]) 

lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
print("el comando lista1[5] devuelve:", lista1[5]) #dato de la 5

print("el comando sum(lista1)/len(lista1) devuelve:", sum(lista1)/len(lista1)) #promedio


lista1.extend(["gbi6", "bio1", "ikiam"]) 
print("tras el extend el comando len(lista1) devuelve:", len(lista1))

lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1] 
print("el comando lista1[8:] devuelve:", lista1[8:])#8 hacia la derecha

lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]
print("el comando round(sum(lista1)/len(lista1), 3) devuelve:", round(sum(lista1)/len(lista1), 3))

# %% [markdown]
# ## Ejercicio 7
#
# Para este ejercicio debe debe realizar lo siguiente:
#
# Crear un diccionario de nombre dic_aminoacidos, donde se tenga la información de la tabla que se encuentra en http://www.russelllab.org/aas/aas.html.
# Utilice como "key" los valores de la columna "AA" y las columnas "Hits" y "%Abundance" como "values".
# Luego de crear el diccionario, extraiga los valores de "key" a una lista de nombre "aminoacidos"
# Extraiga los valores de "value" a una lista de nombre "propiedades"
# Para evaluar esta pregunta realice un git push del Jupyter Notebook al repositorio del examen.
# ### Resolucion en la imagen
# ![ejercicio 7.png](attachment:7d66f750-16f4-466c-8c6f-d8ed21b246c1.png)

# %%
# Codigo
ic_aminoacidos = {"Trp": [1550, 1.34, ], "Cys": [1905, 1.76, ], "His": [1695, 2.26, ], 
                  "Arg": [3093, 5.20, ], "Met": [1102, 2.32, ], "Tyr": [1525, 3.25, ], 
                  "Gln": [1830, 3.96, ], "Phe": [1616, 4.12, ], "Asp": [1691, 5.12, ], 
                  "Pro": [1598, 5.00, ], "Ala": [2018, 7.34, ], "Asn": [1103, 4.57, ], 
                  "Lys": [1366, 5.81, ], "Glu": [1471, 6.22, ], "Gly": [1376, 6.89, ], 
                  "Thr": [1147, 5.85, ], "Val": [1225, 6.48, ], "Ile": [1033, 5.76, ], 
                  "Ser": [1206, 7.38, ], "Leu": [1127, 9.36, ],}
print("Diccionariodic_aminoacidos: ")
print(dic_aminoacidos)

aminoacidos = list(dic_aminoacidos.keys())

print("Lista aminoacidos: ", aminoacidos) 
propiedades = list(dic_aminoacidos.values())

print("Propiedades: ", propiedades)

# %% [markdown]
# ## Ejercicio 8
#
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# En la data https://github.com/sap0408/mtcars/blob/master/mtcars.csv, seleccione los 10 primeros registros y cree una lista de nombre lista1.
#
# Relaciones los códigos y las respuestas que salen al ejecutar.
# ### Resultado en la imagen
# ![Ejercicio 8.png](attachment:890c5b22-9c81-4575-a0e8-a2224a4e0f5b.png)

# %%
lista1 =["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 2400", "Merc 230", "Merc 280"]
lista1.append(["gbi6", "bio1", "ikiam"])
print(lista1[-1][-3])

lista1 =["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 2400", "Merc 230", "Merc 280"]
print(lista1[2:5])

print(lista1[4])

print(lista1[3])

lista1.append(["gbi6", "bio1", "ikiam"])
print(len(lista1))
